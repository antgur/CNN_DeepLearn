# %%
from sklearn.datasets import make_circles
import numpy as np
import matplotlib.pyplot as plt
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"]="2"
def plot_data(pl, X, y):
        # plot class where y==0
    pl.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
    # plot class where y==1
    pl.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
    pl.legend(['0', '1'])
    return pl

# %%
def plot_decision_boundary(model, X, y):
    amin, bmin = X.min(axis=0) - 0.1
    amax, bmax = X.max(axis=0) + 0.1
    hticks = np.linspace(amin, amax, 101)
    vticks = np.linspace(bmin, bmax, 101)
    
    aa, bb = np.meshgrid(hticks, vticks)
    ab = np.c_[aa.ravel(), bb.ravel()]
    
    # make prediction with the model and reshape the output so contourf can plot it
    c = model.predict(ab)
    Z = c.reshape(aa.shape)
    
    plt.figure(figsize=(12, 8))
    # plot the contour
    plt.contourf(aa, bb, Z, cmap='bwr', alpha=0.2)
    # plot the moons of data
    plot_data(plt, X, y)
    
    return plt

# %%
X, y = make_circles(n_samples=1000, factor=.6, noise=0.1, random_state=42)
pl = plot_data(plt, X, y)
pl.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
model = Sequential()
model.add(Dense(4, input_shape=(2,), activation="tanh", name="Hidden-1"))
model.add(Dense(4, activation="tanh", name="Hidden-2"))
model.add(Dense(1, activation="sigmoid", name="Output_layer"))

# %%
model.compile(Adam(lr=0.05), 'binary_crossentropy', metrics=['accuracy'])
from keras.utils import plot_model

# %%
plot_model(model, to_file="model.png", show_shapes=True, show_layer_names=True)

# %%
from keras.callbacks import EarlyStopping
my_callbacks = [EarlyStopping(monitor='val_acc', patience=5, mode=max)]

# %%
model.fit(X_train, y_train, epochs=100, verbose=1, callbacks=my_callbacks, validation_data=(X_test, y_test))
# Out:
# Train on 700 samples, validate on 300 samples
# Epoch 1/100
# 700/700 [==============================] - 0s 156us/step - loss: 0.6893 - accuracy: 0.5300 - val_loss: 0.6930 - val_accuracy: 0.4967
# Epoch 2/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6619 - accuracy: 0.6186 - val_loss: 0.6674 - val_accuracy: 0.5533
# Epoch 3/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6332 - accuracy: 0.6486 - val_loss: 0.6368 - val_accuracy: 0.6233
# Epoch 4/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6021 - accuracy: 0.6943 - val_loss: 0.6070 - val_accuracy: 0.6667
# Epoch 5/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.5511 - accuracy: 0.7500 - val_loss: 0.5585 - val_accuracy: 0.7367
# Epoch 6/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.4121 - accuracy: 0.8571 - val_loss: 0.3507 - val_accuracy: 0.8700
# Epoch 7/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.2635 - accuracy: 0.9143 - val_loss: 0.2128 - val_accuracy: 0.9400
# Epoch 8/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1460 - accuracy: 0.9614 - val_loss: 0.2176 - val_accuracy: 0.9067
# Epoch 9/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1507 - accuracy: 0.9429 - val_loss: 0.1386 - val_accuracy: 0.9533
# Epoch 10/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1007 - accuracy: 0.9657 - val_loss: 0.1630 - val_accuracy: 0.9433
# Epoch 11/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0939 - accuracy: 0.9657 - val_loss: 0.2144 - val_accuracy: 0.9367
# Epoch 12/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1105 - accuracy: 0.9600 - val_loss: 0.1425 - val_accuracy: 0.9467
# Epoch 13/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1041 - accuracy: 0.9571 - val_loss: 0.1359 - val_accuracy: 0.9500
# Epoch 14/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0938 - accuracy: 0.9686 - val_loss: 0.1471 - val_accuracy: 0.9500
# Epoch 15/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0932 - accuracy: 0.9586 - val_loss: 0.1429 - val_accuracy: 0.9467
# Epoch 16/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0995 - accuracy: 0.9600 - val_loss: 0.1696 - val_accuracy: 0.9333
# Epoch 17/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0760 - accuracy: 0.9671 - val_loss: 0.1554 - val_accuracy: 0.9467
# Epoch 18/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0689 - accuracy: 0.9757 - val_loss: 0.1943 - val_accuracy: 0.9333
# Epoch 19/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1067 - accuracy: 0.9571 - val_loss: 0.2149 - val_accuracy: 0.9267
# Epoch 20/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1153 - accuracy: 0.9514 - val_loss: 0.2312 - val_accuracy: 0.9167
# Epoch 21/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1125 - accuracy: 0.9614 - val_loss: 0.1380 - val_accuracy: 0.9433
# Epoch 22/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0745 - accuracy: 0.9714 - val_loss: 0.1107 - val_accuracy: 0.9600
# Epoch 23/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0683 - accuracy: 0.9700 - val_loss: 0.1642 - val_accuracy: 0.9333
# Epoch 24/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0744 - accuracy: 0.9686 - val_loss: 0.1123 - val_accuracy: 0.9500
# Epoch 25/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0846 - accuracy: 0.9686 - val_loss: 0.1611 - val_accuracy: 0.9333
# Epoch 26/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0928 - accuracy: 0.9643 - val_loss: 0.1485 - val_accuracy: 0.9400
# Epoch 27/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0659 - accuracy: 0.9729 - val_loss: 0.1399 - val_accuracy: 0.9500
# Epoch 28/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0931 - accuracy: 0.9614 - val_loss: 0.1211 - val_accuracy: 0.9500
# Epoch 29/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0881 - accuracy: 0.9643 - val_loss: 0.2200 - val_accuracy: 0.9267
# Epoch 30/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0789 - accuracy: 0.9700 - val_loss: 0.1278 - val_accuracy: 0.9533
# Epoch 31/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0613 - accuracy: 0.9757 - val_loss: 0.1076 - val_accuracy: 0.9600
# Epoch 32/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0593 - accuracy: 0.9786 - val_loss: 0.1872 - val_accuracy: 0.9233
# Epoch 33/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0595 - accuracy: 0.9714 - val_loss: 0.2045 - val_accuracy: 0.9333
# Epoch 34/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0812 - accuracy: 0.9686 - val_loss: 0.1279 - val_accuracy: 0.9533
# Epoch 35/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0728 - accuracy: 0.9729 - val_loss: 0.2151 - val_accuracy: 0.9233
# Epoch 36/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1049 - accuracy: 0.9586 - val_loss: 0.1382 - val_accuracy: 0.9500
# Epoch 37/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0584 - accuracy: 0.9771 - val_loss: 0.1361 - val_accuracy: 0.9467
# Epoch 38/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0906 - accuracy: 0.9671 - val_loss: 0.1332 - val_accuracy: 0.9500
# Epoch 39/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0906 - accuracy: 0.9614 - val_loss: 0.1234 - val_accuracy: 0.9533
# Epoch 40/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1041 - accuracy: 0.9614 - val_loss: 0.2061 - val_accuracy: 0.9300
# Epoch 41/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0773 - accuracy: 0.9729 - val_loss: 0.1093 - val_accuracy: 0.9567
# Epoch 42/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0700 - accuracy: 0.9771 - val_loss: 0.1498 - val_accuracy: 0.9567
# Epoch 43/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1025 - accuracy: 0.9586 - val_loss: 0.1762 - val_accuracy: 0.9367
# Epoch 44/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0919 - accuracy: 0.9600 - val_loss: 0.1569 - val_accuracy: 0.9467
# Epoch 45/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0856 - accuracy: 0.9671 - val_loss: 0.1952 - val_accuracy: 0.9400
# Epoch 46/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0748 - accuracy: 0.9686 - val_loss: 0.1615 - val_accuracy: 0.9300
# Epoch 47/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0797 - accuracy: 0.9671 - val_loss: 0.1402 - val_accuracy: 0.9467
# Epoch 48/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1406 - accuracy: 0.9529 - val_loss: 0.1563 - val_accuracy: 0.9433
# Epoch 49/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0660 - accuracy: 0.9729 - val_loss: 0.1851 - val_accuracy: 0.9433
# Epoch 50/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1207 - accuracy: 0.9614 - val_loss: 0.1934 - val_accuracy: 0.9333
# Epoch 51/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0860 - accuracy: 0.9700 - val_loss: 0.1181 - val_accuracy: 0.9533
# Epoch 52/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0625 - accuracy: 0.9743 - val_loss: 0.1527 - val_accuracy: 0.9500
# Epoch 53/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0866 - accuracy: 0.9686 - val_loss: 0.1265 - val_accuracy: 0.9500
# Epoch 54/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0783 - accuracy: 0.9714 - val_loss: 0.1508 - val_accuracy: 0.9367
# Epoch 55/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0906 - accuracy: 0.9614 - val_loss: 0.1905 - val_accuracy: 0.9267
# Epoch 56/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0854 - accuracy: 0.9671 - val_loss: 0.1290 - val_accuracy: 0.9500
# Epoch 57/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0913 - accuracy: 0.9629 - val_loss: 0.2057 - val_accuracy: 0.9333
# Epoch 58/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0965 - accuracy: 0.9600 - val_loss: 0.1326 - val_accuracy: 0.9500
# Epoch 59/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0624 - accuracy: 0.9786 - val_loss: 0.1313 - val_accuracy: 0.9467
# Epoch 60/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0675 - accuracy: 0.9714 - val_loss: 0.1351 - val_accuracy: 0.9467
# Epoch 61/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0659 - accuracy: 0.9743 - val_loss: 0.1084 - val_accuracy: 0.9567
# Epoch 62/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0553 - accuracy: 0.9743 - val_loss: 0.1585 - val_accuracy: 0.9433
# Epoch 63/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0891 - accuracy: 0.9671 - val_loss: 0.2034 - val_accuracy: 0.9433
# Epoch 64/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0738 - accuracy: 0.9743 - val_loss: 0.1708 - val_accuracy: 0.9433
# Epoch 65/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0848 - accuracy: 0.9686 - val_loss: 0.2147 - val_accuracy: 0.9100
# Epoch 66/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0825 - accuracy: 0.9657 - val_loss: 0.1297 - val_accuracy: 0.9433
# Epoch 67/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0661 - accuracy: 0.9700 - val_loss: 0.1245 - val_accuracy: 0.9667
# Epoch 68/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0775 - accuracy: 0.9671 - val_loss: 0.1142 - val_accuracy: 0.9600
# Epoch 69/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0583 - accuracy: 0.9757 - val_loss: 0.1217 - val_accuracy: 0.9567
# Epoch 70/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0761 - accuracy: 0.9729 - val_loss: 0.1990 - val_accuracy: 0.9367
# Epoch 71/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0805 - accuracy: 0.9671 - val_loss: 0.1477 - val_accuracy: 0.9433
# Epoch 72/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0747 - accuracy: 0.9671 - val_loss: 0.1450 - val_accuracy: 0.9533
# Epoch 73/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0731 - accuracy: 0.9700 - val_loss: 0.1297 - val_accuracy: 0.9567
# Epoch 74/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0920 - accuracy: 0.9614 - val_loss: 0.1577 - val_accuracy: 0.9400
# Epoch 75/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0666 - accuracy: 0.9714 - val_loss: 0.1679 - val_accuracy: 0.9400
# Epoch 76/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0649 - accuracy: 0.9657 - val_loss: 0.1149 - val_accuracy: 0.9567
# Epoch 77/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0675 - accuracy: 0.9714 - val_loss: 0.1477 - val_accuracy: 0.9433
# Epoch 78/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0684 - accuracy: 0.9686 - val_loss: 0.1555 - val_accuracy: 0.9500
# Epoch 79/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0883 - accuracy: 0.9643 - val_loss: 0.1272 - val_accuracy: 0.9467
# Epoch 80/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0891 - accuracy: 0.9671 - val_loss: 0.1228 - val_accuracy: 0.9500
# Epoch 81/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1230 - accuracy: 0.9600 - val_loss: 0.1299 - val_accuracy: 0.9467
# Epoch 82/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1003 - accuracy: 0.9643 - val_loss: 0.1271 - val_accuracy: 0.9467
# Epoch 83/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0930 - accuracy: 0.9614 - val_loss: 0.1438 - val_accuracy: 0.9433
# Epoch 84/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0907 - accuracy: 0.9686 - val_loss: 0.1370 - val_accuracy: 0.9533
# Epoch 85/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0576 - accuracy: 0.9757 - val_loss: 0.1112 - val_accuracy: 0.9567
# Epoch 86/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0740 - accuracy: 0.9743 - val_loss: 0.1413 - val_accuracy: 0.9533
# Epoch 87/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0943 - accuracy: 0.9657 - val_loss: 0.2127 - val_accuracy: 0.9233
# Epoch 88/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0968 - accuracy: 0.9614 - val_loss: 0.1467 - val_accuracy: 0.9600
# Epoch 89/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0863 - accuracy: 0.9629 - val_loss: 0.1385 - val_accuracy: 0.9500
# Epoch 90/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0579 - accuracy: 0.9786 - val_loss: 0.1294 - val_accuracy: 0.9500
# Epoch 91/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0590 - accuracy: 0.9786 - val_loss: 0.1673 - val_accuracy: 0.9367
# Epoch 92/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0810 - accuracy: 0.9700 - val_loss: 0.1819 - val_accuracy: 0.9400
# Epoch 93/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0804 - accuracy: 0.9714 - val_loss: 0.1281 - val_accuracy: 0.9567
# Epoch 94/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0574 - accuracy: 0.9743 - val_loss: 0.1753 - val_accuracy: 0.9333
# Epoch 95/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0788 - accuracy: 0.9629 - val_loss: 0.1275 - val_accuracy: 0.9467
# Epoch 96/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0879 - accuracy: 0.9629 - val_loss: 0.1895 - val_accuracy: 0.9333
# Epoch 97/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0788 - accuracy: 0.9729 - val_loss: 0.1405 - val_accuracy: 0.9400
# Epoch 98/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0596 - accuracy: 0.9814 - val_loss: 0.1385 - val_accuracy: 0.9467
# Epoch 99/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0873 - accuracy: 0.9671 - val_loss: 0.2970 - val_accuracy: 0.9133
# Epoch 100/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0782 - accuracy: 0.9643 - val_loss: 0.1350 - val_accuracy: 0.9667

# %%
eval_result = model.evaluate(X_test, y_test)
# Out:
# 300/300 [==============================] - 0s 52us/step

# %%
print("\n\nTest loss:", eval_result[0], "Test accuracy:", eval_result[1])
# Out:
# Test loss: 0.1349909388522307 Test accuracy: 0.9666666388511658

# %%
plot_decision_boundary(model, X, y).show()
