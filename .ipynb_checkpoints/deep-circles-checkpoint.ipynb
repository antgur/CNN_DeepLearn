# %% [markdown]
# # Defines a network that can find separate circles of data

# %%
from sklearn.datasets import make_circles
import numpy as np
import matplotlib.pyplot as plt
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"]="2"

# %%
def plot_data(pl, X, y):
        # plot class where y==0
    pl.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
    # plot class where y==1
    pl.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
    pl.legend(['0', '1'])
    return pl

# %%
def plot_decision_boundary(model, X, y):
    amin, bmin = X.min(axis=0) - 0.1
    amax, bmax = X.max(axis=0) + 0.1
    hticks = np.linspace(amin, amax, 101)
    vticks = np.linspace(bmin, bmax, 101)
    
    aa, bb = np.meshgrid(hticks, vticks)
    ab = np.c_[aa.ravel(), bb.ravel()]
    
    # make prediction with the model and reshape the output so contourf can plot it
    c = model.predict(ab)
    Z = c.reshape(aa.shape)
    
    plt.figure(figsize=(12, 8))
    # plot the contour
    plt.contourf(aa, bb, Z, cmap='bwr', alpha=0.2)
    # plot the moons of data
    plot_data(plt, X, y)
    
    return plt

# %%
X, y = make_circles(n_samples=1000, factor=.6, noise=0.1, random_state=42)

# %%
pl = plot_data(plt, X, y)
pl.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(1, input_shape=(2,), activation="sigmoid"))

# %%
model.compile(Adam(lr=0.05), 'binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 700/700 [==============================] - 0s 89us/step - loss: 0.7046 - accuracy: 0.4957
# Epoch 2/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6939 - accuracy: 0.5014
# Epoch 3/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6948 - accuracy: 0.4657
# Epoch 4/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6963 - accuracy: 0.5086
# Epoch 5/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6949 - accuracy: 0.5500
# Epoch 6/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6963 - accuracy: 0.4800
# Epoch 7/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6943 - accuracy: 0.5343
# Epoch 8/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6966 - accuracy: 0.4500
# Epoch 9/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6948 - accuracy: 0.5929
# Epoch 10/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6960 - accuracy: 0.4686
# Epoch 11/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6937 - accuracy: 0.5800
# Epoch 12/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6938 - accuracy: 0.5600
# Epoch 13/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6940 - accuracy: 0.4786
# Epoch 14/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6957 - accuracy: 0.5086
# Epoch 15/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6960 - accuracy: 0.5143
# Epoch 16/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6949 - accuracy: 0.5171
# Epoch 17/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6937 - accuracy: 0.5557
# Epoch 18/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6949 - accuracy: 0.5100
# Epoch 19/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6948 - accuracy: 0.5114
# Epoch 20/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6945 - accuracy: 0.4671
# Epoch 21/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6966 - accuracy: 0.5286
# Epoch 22/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6960 - accuracy: 0.5271
# Epoch 23/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6954 - accuracy: 0.4557
# Epoch 24/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6954 - accuracy: 0.5514
# Epoch 25/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6958 - accuracy: 0.5271
# Epoch 26/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6989 - accuracy: 0.4671
# Epoch 27/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6946 - accuracy: 0.5257
# Epoch 28/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6944 - accuracy: 0.5329
# Epoch 29/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6954 - accuracy: 0.5271
# Epoch 30/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6955 - accuracy: 0.4557
# Epoch 31/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6968 - accuracy: 0.5686
# Epoch 32/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6963 - accuracy: 0.4400
# Epoch 33/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6940 - accuracy: 0.5743
# Epoch 34/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6943 - accuracy: 0.5157
# Epoch 35/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6958 - accuracy: 0.4957
# Epoch 36/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6950 - accuracy: 0.5357
# Epoch 37/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6947 - accuracy: 0.5529
# Epoch 38/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6933 - accuracy: 0.5671
# Epoch 39/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6951 - accuracy: 0.5386
# Epoch 40/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6953 - accuracy: 0.4400
# Epoch 41/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6949 - accuracy: 0.5314
# Epoch 42/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6953 - accuracy: 0.5071
# Epoch 43/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6961 - accuracy: 0.4314
# Epoch 44/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6950 - accuracy: 0.5429
# Epoch 45/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6955 - accuracy: 0.5286
# Epoch 46/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6967 - accuracy: 0.5043
# Epoch 47/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6945 - accuracy: 0.4843
# Epoch 48/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6954 - accuracy: 0.4343
# Epoch 49/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6954 - accuracy: 0.4843
# Epoch 50/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6947 - accuracy: 0.5129
# Epoch 51/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6962 - accuracy: 0.5029
# Epoch 52/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6955 - accuracy: 0.5843
# Epoch 53/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6958 - accuracy: 0.4314
# Epoch 54/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6952 - accuracy: 0.5143
# Epoch 55/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6940 - accuracy: 0.5200
# Epoch 56/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6947 - accuracy: 0.4500
# Epoch 57/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6968 - accuracy: 0.5186
# Epoch 58/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6961 - accuracy: 0.4300
# Epoch 59/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6956 - accuracy: 0.5257
# Epoch 60/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6969 - accuracy: 0.5229
# Epoch 61/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6939 - accuracy: 0.5186
# Epoch 62/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6947 - accuracy: 0.5243
# Epoch 63/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6961 - accuracy: 0.4986
# Epoch 64/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6941 - accuracy: 0.5429
# Epoch 65/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6952 - accuracy: 0.5629
# Epoch 66/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6940 - accuracy: 0.4914
# Epoch 67/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6962 - accuracy: 0.5343
# Epoch 68/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6940 - accuracy: 0.5171
# Epoch 69/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6948 - accuracy: 0.5486
# Epoch 70/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6979 - accuracy: 0.5000
# Epoch 71/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6952 - accuracy: 0.4357
# Epoch 72/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6958 - accuracy: 0.4957
# Epoch 73/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6960 - accuracy: 0.4729
# Epoch 74/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6956 - accuracy: 0.5114
# Epoch 75/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6961 - accuracy: 0.5257
# Epoch 76/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6956 - accuracy: 0.4143
# Epoch 77/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6945 - accuracy: 0.5371
# Epoch 78/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6961 - accuracy: 0.5000
# Epoch 79/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6946 - accuracy: 0.5443
# Epoch 80/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6952 - accuracy: 0.4529
# Epoch 81/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6936 - accuracy: 0.5700
# Epoch 82/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6938 - accuracy: 0.5243
# Epoch 83/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6955 - accuracy: 0.4414
# Epoch 84/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6945 - accuracy: 0.5714
# Epoch 85/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6983 - accuracy: 0.5057
# Epoch 86/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6950 - accuracy: 0.5529
# Epoch 87/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6943 - accuracy: 0.5457
# Epoch 88/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6976 - accuracy: 0.4486
# Epoch 89/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.7006 - accuracy: 0.5157
# Epoch 90/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6969 - accuracy: 0.4343
# Epoch 91/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6952 - accuracy: 0.5071
# Epoch 92/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6938 - accuracy: 0.5314
# Epoch 93/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6951 - accuracy: 0.4514
# Epoch 94/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6951 - accuracy: 0.5086
# Epoch 95/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6960 - accuracy: 0.4771
# Epoch 96/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6948 - accuracy: 0.5514
# Epoch 97/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6941 - accuracy: 0.5414
# Epoch 98/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6951 - accuracy: 0.4643
# Epoch 99/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6961 - accuracy: 0.5229
# Epoch 100/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6940 - accuracy: 0.5143

# %%
eval_result = model.evaluate(X_test, y_test)
# Out:
# 300/300 [==============================] - 0s 52us/step

# %%
print("\n\nTest loss:", eval_result[0], "Test accuracy:", eval_result[1])
# Out:
# Test loss: 0.6944768937428792 Test accuracy: 0.4866666793823242

# %%
plot_decision_boundary(model, X, y).show()
