# %%
from sklearn.datasets import make_circles
import numpy as np
import matplotlib.pyplot as plt
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"]="2"
def plot_data(pl, X, y):
        # plot class where y==0
    pl.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
    # plot class where y==1
    pl.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
    pl.legend(['0', '1'])
    return pl
def plot_decision_boundary(model, X, y):
    amin, bmin = X.min(axis=0) - 0.1
    amax, bmax = X.max(axis=0) + 0.1
    hticks = np.linspace(amin, amax, 101)
    vticks = np.linspace(bmin, bmax, 101)
    
    aa, bb = np.meshgrid(hticks, vticks)
    ab = np.c_[aa.ravel(), bb.ravel()]
    
    # make prediction with the model and reshape the output so contourf can plot it
    c = model.predict(ab)
    Z = c.reshape(aa.shape)
    
    plt.figure(figsize=(12, 8))
    # plot the contour
    plt.contourf(aa, bb, Z, cmap='bwr', alpha=0.2)
    # plot the moons of data
    plot_data(plt, X, y)
    
    return plt

# %%
X, y = make_circles(n_samples=1000, factor=.6, noise=0.1, random_state=42)
pl = plot_data(plt, X, y)
pl.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(4, input_shape=(2,), activation="tanh", name="Hidden-1"))
model.add(Dense(4, activation="tanh", name="Hidden-2"))
model.add(Dense(1, activation="sigmoid", name="Output_layer"))

# %%
model.compile(Adam(lr=0.05), 'binary_crossentropy', metrics=['accuracy'])
from keras.utils import plot_model
plot_model(model, to_file="model.png", show_shapes=True, show_layer_names=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pydot.py in create(self, prog, format, encoding)
#    1914                 arguments=arguments,
# -> 1915                 working_dir=tmp_dir,
#    1916             )
#
# ~\Anaconda3\lib\site-packages\pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     135         stdout=subprocess.PIPE,
# --> 136         **kwargs
#     137     )
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ~\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1177                                          os.fspath(cwd) if cwd is not None else None,
# -> 1178                                          startupinfo)
#    1179             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\keras\utils\vis_utils.py in _check_pydot()
#      27         # to check the pydot/graphviz installation.
# ---> 28         pydot.Dot.create(pydot.Dot())
#      29     except OSError:
#
# ~\Anaconda3\lib\site-packages\pydot.py in create(self, prog, format, encoding)
#    1921                     prog=prog)
# -> 1922                 raise OSError(*args)
#    1923             else:
#
# FileNotFoundError: [WinError 2] "dot" not found in path.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-01dda259c2db> in <module>
#       1 model.compile(Adam(lr=0.05), 'binary_crossentropy', metrics=['accuracy'])
#       2 from keras.utils import plot_model
# ----> 3 plot_model(model, to_file="model.png", show_shapes=True, show_layer_names=True)
#
# ~\Anaconda3\lib\site-packages\keras\utils\vis_utils.py in plot_model(model, to_file, show_shapes, show_layer_names, rankdir, expand_nested, dpi)
#     238     """
#     239     dot = model_to_dot(model, show_shapes, show_layer_names, rankdir,
# --> 240                        expand_nested, dpi)
#     241     _, extension = os.path.splitext(to_file)
#     242     if not extension:
#
# ~\Anaconda3\lib\site-packages\keras\utils\vis_utils.py in model_to_dot(model, show_shapes, show_layer_names, rankdir, expand_nested, dpi, subgraph)
#      77     from ..models import Sequential
#      78
# ---> 79     _check_pydot()
#      80     if subgraph:
#      81         dot = pydot.Cluster(style='dashed', graph_name=model.name)
#
# ~\Anaconda3\lib\site-packages\keras\utils\vis_utils.py in _check_pydot()
#      29     except OSError:
#      30         raise OSError(
# ---> 31             '`pydot` failed to call GraphViz.'
#      32             'Please install GraphViz (https://www.graphviz.org/) '
#      33             'and ensure that its executables are in the $PATH.')
#
# OSError: `pydot` failed to call GraphViz.Please install GraphViz (https://www.graphviz.org/) and ensure that its executables are in the $PATH.

# %%
model.fit(X_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 700/700 [==============================] - 0s 134us/step - loss: 0.6909 - accuracy: 0.5443
# Epoch 2/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.6396 - accuracy: 0.7000
# Epoch 3/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.4871 - accuracy: 0.8486
# Epoch 4/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.3259 - accuracy: 0.9086
# Epoch 5/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.2341 - accuracy: 0.9414
# Epoch 6/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1713 - accuracy: 0.9500
# Epoch 7/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1466 - accuracy: 0.9571
# Epoch 8/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1154 - accuracy: 0.9657
# Epoch 9/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1186 - accuracy: 0.9600
# Epoch 10/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1200 - accuracy: 0.9629
# Epoch 11/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1728 - accuracy: 0.9300
# Epoch 12/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1313 - accuracy: 0.9557
# Epoch 13/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0877 - accuracy: 0.9743
# Epoch 14/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0770 - accuracy: 0.9671
# Epoch 15/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0964 - accuracy: 0.9629
# Epoch 16/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0813 - accuracy: 0.9743
# Epoch 17/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0703 - accuracy: 0.9771
# Epoch 18/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0725 - accuracy: 0.9771
# Epoch 19/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0670 - accuracy: 0.9800
# Epoch 20/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0654 - accuracy: 0.9714
# Epoch 21/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0641 - accuracy: 0.9743
# Epoch 22/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0552 - accuracy: 0.9800
# Epoch 23/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0781 - accuracy: 0.9671
# Epoch 24/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0636 - accuracy: 0.9800
# Epoch 25/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0864 - accuracy: 0.9714
# Epoch 26/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0760 - accuracy: 0.9771
# Epoch 27/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0738 - accuracy: 0.9729
# Epoch 28/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0748 - accuracy: 0.9714
# Epoch 29/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0983 - accuracy: 0.9629
# Epoch 30/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0899 - accuracy: 0.9657
# Epoch 31/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0573 - accuracy: 0.9757
# Epoch 32/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0609 - accuracy: 0.9800
# Epoch 33/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0654 - accuracy: 0.9729
# Epoch 34/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0695 - accuracy: 0.9714
# Epoch 35/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0522 - accuracy: 0.9829
# Epoch 36/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0803 - accuracy: 0.9729
# Epoch 37/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0748 - accuracy: 0.9700
# Epoch 38/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0635 - accuracy: 0.9743
# Epoch 39/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0597 - accuracy: 0.9757
# Epoch 40/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0694 - accuracy: 0.9757
# Epoch 41/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0609 - accuracy: 0.9743
# Epoch 42/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1118 - accuracy: 0.9586
# Epoch 43/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0746 - accuracy: 0.9657
# Epoch 44/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0579 - accuracy: 0.9729
# Epoch 45/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0758 - accuracy: 0.9671
# Epoch 46/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0846 - accuracy: 0.9700
# Epoch 47/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0703 - accuracy: 0.9714
# Epoch 48/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0625 - accuracy: 0.9786
# Epoch 49/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0648 - accuracy: 0.9714
# Epoch 50/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0724 - accuracy: 0.9743
# Epoch 51/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0548 - accuracy: 0.9786
# Epoch 52/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0557 - accuracy: 0.9743
# Epoch 53/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0708 - accuracy: 0.9657
# Epoch 54/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0654 - accuracy: 0.9743
# Epoch 55/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0707 - accuracy: 0.9729
# Epoch 56/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0763 - accuracy: 0.9714
# Epoch 57/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0486 - accuracy: 0.9771
# Epoch 58/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0741 - accuracy: 0.9757
# Epoch 59/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0677 - accuracy: 0.9729
# Epoch 60/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0522 - accuracy: 0.9829
# Epoch 61/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0581 - accuracy: 0.9757
# Epoch 62/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0529 - accuracy: 0.9800
# Epoch 63/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0539 - accuracy: 0.9771
# Epoch 64/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0708 - accuracy: 0.9771
# Epoch 65/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0530 - accuracy: 0.9800
# Epoch 66/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0763 - accuracy: 0.9714
# Epoch 67/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0710 - accuracy: 0.9743
# Epoch 68/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0834 - accuracy: 0.9686
# Epoch 69/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0706 - accuracy: 0.9757
# Epoch 70/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0780 - accuracy: 0.9700
# Epoch 71/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0498 - accuracy: 0.9786
# Epoch 72/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0520 - accuracy: 0.9771
# Epoch 73/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0558 - accuracy: 0.9771
# Epoch 74/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0584 - accuracy: 0.9743
# Epoch 75/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1123 - accuracy: 0.9557
# Epoch 76/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0784 - accuracy: 0.9729
# Epoch 77/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0833 - accuracy: 0.9671
# Epoch 78/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0663 - accuracy: 0.9743
# Epoch 79/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0827 - accuracy: 0.9743
# Epoch 80/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0837 - accuracy: 0.9686
# Epoch 81/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0822 - accuracy: 0.9700
# Epoch 82/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0766 - accuracy: 0.9700
# Epoch 83/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0621 - accuracy: 0.9757
# Epoch 84/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0510 - accuracy: 0.9843
# Epoch 85/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0538 - accuracy: 0.9800
# Epoch 86/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0745 - accuracy: 0.9700
# Epoch 87/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0782 - accuracy: 0.9714
# Epoch 88/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0654 - accuracy: 0.9743
# Epoch 89/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0610 - accuracy: 0.9771
# Epoch 90/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0521 - accuracy: 0.9800
# Epoch 91/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0495 - accuracy: 0.9800
# Epoch 92/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0874 - accuracy: 0.9686
# Epoch 93/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0525 - accuracy: 0.9757
# Epoch 94/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0594 - accuracy: 0.9786
# Epoch 95/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0590 - accuracy: 0.9771
# Epoch 96/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0830 - accuracy: 0.9686
# Epoch 97/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0771 - accuracy: 0.9743
# Epoch 98/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0607 - accuracy: 0.9757
# Epoch 99/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0628 - accuracy: 0.9743
# Epoch 100/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0610 - accuracy: 0.9800

# %%
eval_result = model.evaluate(X_test, y_test)
# Out:
# 300/300 [==============================] - 0s 52us/step

# %%
print("\n\nTest loss:", eval_result[0], "Test accuracy:", eval_result[1])
# Out:
# Test loss: 0.12189123469094436 Test accuracy: 0.95333331823349

# %%
plot_decision_boundary(model, X, y).show()
