# %%
from sklearn.datasets import make_circles
import numpy as np
import matplotlib.pyplot as plt
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"]="2"
def plot_data(pl, X, y):
        # plot class where y==0
    pl.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
    # plot class where y==1
    pl.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
    pl.legend(['0', '1'])
    return pl
def plot_decision_boundary(model, X, y):
    amin, bmin = X.min(axis=0) - 0.1
    amax, bmax = X.max(axis=0) + 0.1
    hticks = np.linspace(amin, amax, 101)
    vticks = np.linspace(bmin, bmax, 101)
    
    aa, bb = np.meshgrid(hticks, vticks)
    ab = np.c_[aa.ravel(), bb.ravel()]
    
    # make prediction with the model and reshape the output so contourf can plot it
    c = model.predict(ab)
    Z = c.reshape(aa.shape)
    
    plt.figure(figsize=(12, 8))
    # plot the contour
    plt.contourf(aa, bb, Z, cmap='bwr', alpha=0.2)
    # plot the moons of data
    plot_data(plt, X, y)
    
    return plt

# %%
X, y = make_circles(n_samples=1000, factor=.6, noise=0.1, random_state=42)
pl = plot_data(plt, X, y)
pl.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(4, input_shape=(2,), activation="tanh", name="Hidden-1"))
model.add(Dense(4, activation="tanh", name="Hidden-2"))
model.add(Dense(1, activation="sigmoid", name="Output_layer"))

# %%
model.compile(Adam(lr=0.05), 'binary_crossentropy', metrics=['accuracy'])
from keras.utils import plot_model

# %%
plot_model(model, to_file="model.png", show_shapes=True, show_layer_names=True)

# %%
model.fit(X_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 700/700 [==============================] - 0s 134us/step - loss: 0.6855 - accuracy: 0.5657
# Epoch 2/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.6301 - accuracy: 0.6771
# Epoch 3/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.5247 - accuracy: 0.8286
# Epoch 4/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.3734 - accuracy: 0.8743
# Epoch 5/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.2657 - accuracy: 0.9143
# Epoch 6/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.2196 - accuracy: 0.9371
# Epoch 7/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1767 - accuracy: 0.9514
# Epoch 8/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1595 - accuracy: 0.9543
# Epoch 9/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1448 - accuracy: 0.9600
# Epoch 10/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1246 - accuracy: 0.9600
# Epoch 11/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1233 - accuracy: 0.9614
# Epoch 12/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1039 - accuracy: 0.9671
# Epoch 13/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1040 - accuracy: 0.9700
# Epoch 14/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1066 - accuracy: 0.9714
# Epoch 15/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1204 - accuracy: 0.9600
# Epoch 16/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1215 - accuracy: 0.9557
# Epoch 17/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1386 - accuracy: 0.9471
# Epoch 18/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0959 - accuracy: 0.9671
# Epoch 19/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0999 - accuracy: 0.9657
# Epoch 20/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0985 - accuracy: 0.9643
# Epoch 21/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0867 - accuracy: 0.9686
# Epoch 22/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0829 - accuracy: 0.9714
# Epoch 23/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0710 - accuracy: 0.9757
# Epoch 24/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0716 - accuracy: 0.9800
# Epoch 25/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0732 - accuracy: 0.9729
# Epoch 26/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0947 - accuracy: 0.9629
# Epoch 27/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0691 - accuracy: 0.9757
# Epoch 28/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0695 - accuracy: 0.9700
# Epoch 29/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0845 - accuracy: 0.9714
# Epoch 30/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0873 - accuracy: 0.9700
# Epoch 31/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0801 - accuracy: 0.9671
# Epoch 32/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0833 - accuracy: 0.9700
# Epoch 33/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0758 - accuracy: 0.9700
# Epoch 34/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0701 - accuracy: 0.9771
# Epoch 35/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0787 - accuracy: 0.9671
# Epoch 36/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0683 - accuracy: 0.9700
# Epoch 37/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0816 - accuracy: 0.9714
# Epoch 38/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0680 - accuracy: 0.9729
# Epoch 39/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0689 - accuracy: 0.9714
# Epoch 40/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0671 - accuracy: 0.9771
# Epoch 41/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1144 - accuracy: 0.9571
# Epoch 42/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0947 - accuracy: 0.9671
# Epoch 43/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0757 - accuracy: 0.9714
# Epoch 44/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0733 - accuracy: 0.9743
# Epoch 45/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0692 - accuracy: 0.9700
# Epoch 46/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0555 - accuracy: 0.9800
# Epoch 47/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0664 - accuracy: 0.9800
# Epoch 48/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0658 - accuracy: 0.9729
# Epoch 49/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0513 - accuracy: 0.9829
# Epoch 50/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1227 - accuracy: 0.9529
# Epoch 51/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1082 - accuracy: 0.9614
# Epoch 52/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0728 - accuracy: 0.9700
# Epoch 53/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0639 - accuracy: 0.9757
# Epoch 54/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0721 - accuracy: 0.9729
# Epoch 55/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0636 - accuracy: 0.9771
# Epoch 56/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0772 - accuracy: 0.9771
# Epoch 57/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0597 - accuracy: 0.9843
# Epoch 58/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0603 - accuracy: 0.9786
# Epoch 59/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0669 - accuracy: 0.9714
# Epoch 60/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0758 - accuracy: 0.9729
# Epoch 61/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0590 - accuracy: 0.9800
# Epoch 62/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0768 - accuracy: 0.9700
# Epoch 63/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1049 - accuracy: 0.9600
# Epoch 64/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0657 - accuracy: 0.9814
# Epoch 65/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0838 - accuracy: 0.9700
# Epoch 66/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0861 - accuracy: 0.9700
# Epoch 67/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0707 - accuracy: 0.9714
# Epoch 68/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0675 - accuracy: 0.9729
# Epoch 69/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0728 - accuracy: 0.9729
# Epoch 70/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0558 - accuracy: 0.9814
# Epoch 71/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0579 - accuracy: 0.9786
# Epoch 72/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0668 - accuracy: 0.9714
# Epoch 73/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0537 - accuracy: 0.9800
# Epoch 74/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0602 - accuracy: 0.9786
# Epoch 75/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0503 - accuracy: 0.9814
# Epoch 76/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0722 - accuracy: 0.9686
# Epoch 77/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1051 - accuracy: 0.9686
# Epoch 78/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0686 - accuracy: 0.9729
# Epoch 79/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0759 - accuracy: 0.9714
# Epoch 80/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0718 - accuracy: 0.9743
# Epoch 81/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0774 - accuracy: 0.9743
# Epoch 82/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0735 - accuracy: 0.9743
# Epoch 83/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0800 - accuracy: 0.9686
# Epoch 84/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0590 - accuracy: 0.9786
# Epoch 85/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0762 - accuracy: 0.9714
# Epoch 86/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.1170 - accuracy: 0.9571
# Epoch 87/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0714 - accuracy: 0.9729
# Epoch 88/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.1045 - accuracy: 0.9657
# Epoch 89/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0910 - accuracy: 0.9671
# Epoch 90/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0784 - accuracy: 0.9700
# Epoch 91/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0974 - accuracy: 0.9629
# Epoch 92/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0696 - accuracy: 0.9757
# Epoch 93/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0669 - accuracy: 0.9714
# Epoch 94/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0616 - accuracy: 0.9800
# Epoch 95/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0517 - accuracy: 0.9814
# Epoch 96/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0659 - accuracy: 0.9743
# Epoch 97/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0719 - accuracy: 0.9729
# Epoch 98/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0826 - accuracy: 0.9743
# Epoch 99/100
# 700/700 [==============================] - 0s 45us/step - loss: 0.0674 - accuracy: 0.9757
# Epoch 100/100
# 700/700 [==============================] - 0s 22us/step - loss: 0.0680 - accuracy: 0.9757

# %%
eval_result = model.evaluate(X_test, y_test)
# Out:
# 300/300 [==============================] - 0s 52us/step

# %%
print("\n\nTest loss:", eval_result[0], "Test accuracy:", eval_result[1])
# Out:
# Test loss: 0.18132687419652938 Test accuracy: 0.9300000071525574

# %%
plot_decision_boundary(model, X, y).show()
